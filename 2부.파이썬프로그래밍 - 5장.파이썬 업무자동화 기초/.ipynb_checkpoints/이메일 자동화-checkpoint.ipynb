# %% [markdown]
# # smtp

# %% [markdown]
# ## Gmail

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "inbox@fininsight.co.kr"  # Enter your address
receiver_email = "inbox@fininsight.co.kr"  # Enter receiver address
password = '' #input("Type your password and press enter: ")
message = """\
Subject: 재미있는 파이썬 업무자동화

파이썬 업무자동화로 보내는 메일입니다.
와우 신난다.."""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-1-8fed92ebbaba> in <module>()
#      13 context = ssl.create_default_context()
#      14 with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
# ---> 15     server.login(sender_email, password)
#      16     server.sendmail(sender_email, receiver_email, message)
#
# ~/anaconda3/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~/anaconda3/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# ~/anaconda3/lib/python3.6/smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (501, b'5.5.2 Cannot Decode response v62sm12934778pfk.72 - gsmtp')

# %% [markdown]
# ## Naver mail

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.naver.com"
sender_email = "eminoart@naver.com"  # Enter your address
receiver_email = "inbox@fininsight.co.kr"  # Enter receiver address
password = #input("Type your password and press enter: ")
message = """\
Subject: 재미있는 파이썬 업무자동화

파이썬 업무자동화로 보내는 메일입니다.
와우 신난다.."""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-18-e63d00b8f5d4> in <module>()
#      13 context = ssl.create_default_context()
#      14 with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
# ---> 15     server.login(sender_email, password)
#      16     server.sendmail(sender_email, receiver_email, message)
#
# ~/anaconda3/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~/anaconda3/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# ~/anaconda3/lib/python3.6/smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.1 Username and Password not accepted -CouScAFSC2BPVMeLNyYsQ - nsmtp')

# %%
import poplib
import string, random
from io import StringIO
#import rfc822py3 as rfc822 # import rfc822 #mimelib
import logging

SERVER = "pop.gmail.com"
USER  = "inbox@fininsight.co.kr"
PASSWORD = ""

# connect to server
logging.debug('connecting to ' + SERVER)
server = poplib.POP3_SSL(SERVER)
#server = poplib.POP3(SERVER)

# login
logging.debug('logging in')
server.user(USER)
server.pass_(PASSWORD)

# list items on server
logging.debug('listing emails')
resp, items, octets = server.list()

print()

# download the first message in the list
id, size = items[0].split()
tt = server.retr(1)
print(tt)
#resp, text, octets = server.retr(id)

# convert list to Message object
text = string.join(text, "\n")
print(text)
#file = StringIO.StringIO(text)
#print(file)
#message = rfc822.Message(file)

# output message
#print(message['From']),
#print(message['Subject']),
#print(message['Date']),
#print(message.fp.read())
# Out:
# (b'+OK message follows', [b'Delivered-To: edu@fininsight.co.kr', b'Received: by 10.55.127.195 with SMTP id a186csp163127qkd;', b'        Wed, 7 Dec 2016 00:59:59 -0800 (PST)', b'X-Received: by 10.233.221.135 with SMTP id r129mr57933271qkf.56.1481101198968;', b'        Wed, 07 Dec 2016 00:59:58 -0800 (PST)', b'Received: from 279448736670', b'\tnamed unknown', b'\tby gmailapi.google.com', b'\twith HTTPREST;', b'\tWed, 7 Dec 2016 00:59:58 -0800', b'Reply-To: "Works Mobile" <works_admin@worksmobile.com>', b'From: "Works Mobile" <works_admin@worksmobile.com>', b'To: =?utf-8?B?7J247IKs7J207Yq47Lqg7Y287Iqk?= <edu@fininsight.co.kr>', b'Subject: =?utf-8?B?W1dvcmtzIE1vYmlsZV0g7LKrIOuwqeusuOydhCDtmZjsmIHtlanri4jri6Qu?=', b'Date: Tue, 8 Mar 2016 15:32:03 +0900', b'Message-ID: <1457418723761.13050.1075834@cvplowl03.wmail>', b'MIME-Version: 1.0', b'Content-Type: multipart/alternative;', b'\tboundary="----=_NextPart_000_08CA_01D250B3.B631C9D0"', b'X-Mailer: Microsoft Outlook 16.0', b'Thread-Index: AQJAG5Qgs23oa1AA+iGedNw0F+evXQ==', b'x-google-migrated: true', b'', b'This is a multipart message in MIME format.', b'', b'------=_NextPart_000_08CA_01D250B3.B631C9D0', b'Content-Type: text/plain;', b'\tcharset="utf-8"', b'Content-Transfer-Encoding: 8bit', b'', b'', b'', b'  <https://ssl.pstatic.net/static/pwe/common/logo_works_mobile_retina.png>', b'fininsight.co.kr \xea\xb0\x80\xec\x9e\x85 \xec\x99\x84\xeb\xa3\x8c \xec\x95\x88\xeb\x82\xb4\xec\x95\x88\xeb\x85\x95\xed\x95\x98\xec\x84\xb8\xec\x9a\x94. Works Mobile \xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4.', b'\xec\x9d\xb8\xec\x82\xac\xec\x9d\xb4\xed\x8a\xb8\xec\xba\xa0\xed\x8d\xbc\xec\x8a\xa4\xeb\x8b\x98\xec\x9d\x98 fininsight.co.kr \xea\xb3\x84\xec\xa0\x95\xec\x9d\xb4 \xec\x95\x84\xeb\x9e\x98\xec\x99\x80 \xea\xb0\x99\xec\x9d\xb4 \xec\x83\x9d\xec\x84\xb1\xeb\x90\x98\xec\x96\xb4', b'\xec\xa7\x80\xea\xb8\x88\xeb\xb6\x80\xed\x84\xb0 \xeb\xb0\x94\xeb\xa1\x9c Works Mobile \xec\x84\x9c\xeb\xb9\x84\xec\x8a\xa4\xeb\xa5\xbc \xec\x9d\xb4\xec\x9a\xa9\xed\x95\x98\xec\x8b\xa4 \xec\x88\x98 \xec\x9e\x88\xec\x8a\xb5\xeb\x8b\x88